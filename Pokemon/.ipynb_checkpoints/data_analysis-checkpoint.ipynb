# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm, skew
from sklearn.preprocessing import StandardScaler
from scipy import stats
from scipy.stats.stats import pearsonr
import matplotlib
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score

data = pd.read_csv('pokemon.csv', index_col="Number")

# %%
print data.head()
# Out:
#               Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# Number
# 1        Bulbasaur  Grass  Poison    318  45      49       49      65      65
# 2          Ivysaur  Grass  Poison    405  60      62       63      80      80
# 3         Venusaur  Grass  Poison    525  80      82       83     100     100
# 4       Charmander   Fire     NaN    309  39      52       43      60      50
# 5       Charmeleon   Fire     NaN    405  58      64       58      80      65
#
#         Speed       ...        Color hasGender Pr_Male Egg_Group_1  \
# Number              ...
# 1          45       ...        Green      True   0.875     Monster
# 2          60       ...        Green      True   0.875     Monster
# 3          80       ...        Green      True   0.875     Monster
# 4          65       ...          Red      True   0.875     Monster
# 5          80       ...          Red      True   0.875     Monster
#
# ...

# %%
data['isLegendary'].value_counts()
# Out:
# False    675
# True      46
# Name: isLegendary, dtype: int64

# %%
data.plot(kind='scatter', x='Weight_kg', y='isLegendary');
plt.show()

# %%
data.plot(kind="scatter", x="Attack", y="Defense");
plt.show()

# %%
sns.FacetGrid(data, hue="Body_Style", size=5) \
   .map(plt.scatter, "Height_m", "Weight_kg") \
   .add_legend()
plt.show()

# %%
data['Body_Style'].describe()
# Out:
# count                721
# unique                14
# top       bipedal_tailed
# freq                 158
# Name: Body_Style, dtype: object

# %%
corrmat = data.corr()
f, ax = plt.subplots(figsize=(8,5));
sns.heatmap(corrmat, vmax=.8, square=True);
plt.show()

# %%
# sns.boxplot(x="isLegendary", y="hasGender", data=data);
ax = sns.stripplot(x="hasGender", y="isLegendary", data=data, jitter=True, edgecolor="gray");
plt.show()

# %%
x = pd.concat([data['isLegendary'], data['hasGender']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='hasGender', y="isLegendary", data=x)
# fig.axis(ymin=0, ymax=2);
plt.show()

# %%
a_data = pd.concat([data['Total'], data['Catch_Rate']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='Catch_Rate', y="Total", data=a_data)
# fig.axis(ymin=0, ymax=2);
plt.show()

# %%
a_data.plot.scatter(x='Catch_Rate', y='Total');
plt.show()

# %%
data['isLegendary'].hist();
plt.show()

# %%
data['hasGender'].hist();
plt.show()

# %%
data['hasMegaEvolution'].hist();
plt.show()

# %%
# Out:
#               Name    Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# Number
# 1        Bulbasaur     Grass  Poison    318   45      49       49      65
# 2          Ivysaur     Grass  Poison    405   60      62       63      80
# 3         Venusaur     Grass  Poison    525   80      82       83     100
# 4       Charmander      Fire     NaN    309   39      52       43      60
# 5       Charmeleon      Fire     NaN    405   58      64       58      80
# 6        Charizard      Fire  Flying    534   78      84       78     109
# 7         Squirtle     Water     NaN    314   44      48       65      50
# 8        Wartortle     Water     NaN    405   59      63       80      65
# 9        Blastoise     Water     NaN    530   79      83      100      85
# 10        Caterpie       Bug     NaN    195   45      30       35      20
# 11         Metapod       Bug     NaN    205   50      20       55      25
# 12      Butterfree       Bug  Flying    395   60      45       50      90
# ...
