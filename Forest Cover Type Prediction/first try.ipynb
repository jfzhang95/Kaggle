# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# # 无缺失值, 每个cover种类平衡

# %%
print train['Cover_Type'].value_counts()
# Out:
# 7    2160
# 6    2160
# 5    2160
# 4    2160
# 3    2160
# 2    2160
# 1    2160
# Name: Cover_Type, dtype: int64

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Elevation") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Aspect") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Slope") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Horizontal_Distance_To_Hydrology") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Vertical_Distance_To_Hydrology") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Horizontal_Distance_To_Roadways") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Hillshade_9am") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Hillshade_Noon") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Hillshade_3pm") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(train, hue="Cover_Type", size=6) \
   .map(sns.kdeplot, "Horizontal_Distance_To_Fire_Points") \
   .add_legend()
plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_features = PolynomialFeatures(interaction_only=True)
